# %% [markdown]
# # 06 — Bootstrap & Symmetry Metrics
# Run the analyzer and inspect bootstrap stability and symmetry distance.

# %%
import pandas as pd
from triality_qutrit.stats import symmetry_distance, bootstrap_hotspot
df = pd.read_csv('../data/synthetic/triad_sweep.csv')
sym = symmetry_distance(df)
boot_df, boot_sum = bootstrap_hotspot(df, n_boot=200)
sym, boot_sum, boot_df.head()
