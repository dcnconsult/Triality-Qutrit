# %% [markdown]
# # 02 — Hotspot Significance
# Pre-registered shuffle test for spatial structure + locate peak.

# %%
import pandas as pd
from triality_qutrit.stats import spatial_signal_to_noise, hotspot_peak
df = pd.read_csv('../data/synthetic/triad_sweep.csv')
stats = spatial_signal_to_noise(df, n_shuffle=200)
peak = hotspot_peak(df)
stats, peak
