# %% [markdown]
# # 01 — Visualize Coherence Map
# Load the sweep and plot a T2* heatmap.

# %%
import pandas as pd
from triality_qutrit.plotting import heatmap
df = pd.read_csv('../data/synthetic/triad_sweep.csv')
heatmap(df, out='../out/heatmap_T2star.png')
df.head()
